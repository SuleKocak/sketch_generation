# %% [markdown]
# <h1><center></center></h1>
# <div style="display: flex; justify-content: center; margin: 0 auto;" align="center">
#   <img src="https://myth-ai.com/wp-content/uploads/2023/05/646f153be1e56.png" href="https://myth-ai.com/" width="100px" align="center">
#   <h1>Technical Assignment</h1>
# </div>
#
# <div align="center">
#   <h2>
#   Sketch Generation via Diffusion Models using Sequential Strokes
#   </h2>
# </div>
#
#
# <div align="center">
#   <img src="https://github.com/googlecreativelab/quickdraw-dataset/blob/master/preview.jpg?raw=true">
#   <figcaption>
#     Collection of 50 million drawings across 345 categories, contributed by players of the game Quick, Draw!. Drawings were captured as timestamped vectors.
#     <i>Source: <a href="https://quickdraw.withgoogle.com/data/">Quick, Draw! Dataset</a>.</i>
#   </figcaption>
# </div>
#
# ---
#
# ## Objective
#
# In this project, you are expected to implement a **conditional generative diffusion model** that learns to generate hand-drawn sketches in a **stroke-by-stroke** sequential manner. Rather than generating the entire sketch at once, your model should mimic the **sequential nature of human drawing**, producing strokes one after another in a realistic and interpretable way.
#
# You will use the [Quick, Draw!](https://quickdraw.withgoogle.com/data/) dataset released by Google, which provides timestamped vector representations of user-drawn sketches across 345 object categories.
#
# ---
#
# ## Brief Explanation
#
# You will design and train a **separate conditional diffusion model** for each of the following three categories:
#
# - `cat`
# - `bus`
# - `rabbit`
#
# Each model must learn to generate sketches from that category using **sequential stroke data**. That means you will build **three separate models** in total—one per category.
#
# Your implementation must be documented in a reproducible Jupyter notebook, including training steps, visualizations, and both qualitative and quantitative evaluations.
#
# - Include comprehensive documentation of your approach and design decisions.
# - Provide clear training procedures, model architecture explanations, and inference code.
# - Ensure full reproducibility (running all cells should yield consistent results with fixed random seeds).
#
# ---
#
# ## Data Specification
#
# The Quick, Draw! dataset includes over 50 million sketches in vector format, with each sketch consisting of multiple strokes, where each stroke is a sequence of coordinates (`x`, `y`) along with timing information.
#
# You can download the raw `.ndjson` files from the this [section](#cell-id1). The following commands will download the required categories (`cat`, `bus`, `rabbit`) into the ./data directory.
#
# **⚠️ Note:** If you're not using Google Colab or Kaggle, make sure you have `gsutil` installed. You can install it via pip:
#
# ```bash
# pip install gsutil
# ```
#
# **⚠️ Important:** The dataset files are in [NDJSON](https://github.com/ndjson/ndjson-spec) format. Make sure to install the ndjson Python module before attempting to parse the files.
#
# ```bash
# pip install ndjson
# ```
#
# ### Train/Test Subsets for Target Categories
#
# After downloading the dataset in the `./data` directory, extract the provided `subset.zip` file. This archive includes the predefined train/test splits for each of the three categories.
#
# ```
# subset/
# ├── cat/
# │  └── indices.json
# ├── bus/
# │  └── indices.json
# └── rabbit/
# │  └── indices.json
# ```
#
# Each `indices` file contains a JSON structure with two keys:
#
# - `"train"`: list of indices for training
# - `"test"`: list of indices for testing
#
# **⚠️ Important:** Strictly adhere to these predefined splits for consistent evaluation.
#
#
# ---
#
#
# ## Evaluation
#
# You must evaluate your model both **qualitatively** and **quantitatively**.
#
# ### Quantitative Evaluation
#
# Use the following metrics to compare the real test set sketches with those generated by your model:
#
# - **FID (Fréchet Inception Distance)**
# - **KID (Kernel Inception Distance)**
#
# These metrics should be computed **separately for each category** using the sketches indexed under the `"test"` key in each category’s `indices.json` file.
#
# > **Final submission must include three FID and three KID scores—one pair per category.**
#
# ### Qualitative Evaluation
#
# Provide visual demonstrations including:
#
# - Sample generated sketches for each category.
# - Your submission must include three animated GIFs (one per category) showing the stroke-by-stroke generation process, similar to `example.gif` file in the link.
# - Comparison between real and generated sketches.
#
#
# ---
#
#
# ## Deliverables
#
# Your submission should include the following:
#
# - A well-structured **Jupyter Notebook** that:
#   - Explains your approach and design decisions
#   - Implements the conditional diffusion model
#   - Includes training procedure and inference pipeline code
#   - Presents both qualitative and quantitative results
#   - Visual examples of generated sketches for each of the 3 categories
#   - Animated GIFs demonstrating progressive sketch generation (similar to the provided example.gif)
#   - Clearly computed FID/KID scores for each category
# - Model performance analysis across categories
# - Comparison of generated vs. real sketch characteristics
# - Discussion of limitations and potential improvements
#
#
# > 🔒 All visualizations must be based on sketches generated by your own model. Using samples from external sources will be considered **plagiarism** and will result in disqualification.
#
# > 🔁 The notebook must be **fully reproducible**: running all cells from top to bottom should produce the same results (assuming fixed random seed).
#
# ---
#
# ## Acknowledgements
#
# - [The Quick, Draw! Dataset](https://github.com/googlecreativelab/quickdraw-dataset)
# - [Quick, Draw! Kaggle Competition](https://www.kaggle.com/c/quickdraw-doodle-recognition/overview)
# - [Diffusion Models Overview (Lil’Log)](https://lilianweng.github.io/posts/2021-07-11-diffusion-models/)
# - [Ha, D., & Eck, D. (2017). A neural representation of sketch drawings. arXiv preprint arXiv:1704.03477.](https://arxiv.org/pdf/1704.03477)
# - Special thanks to M. Sung, KAIST

# %% [markdown]
# # Download the Quick, Draw! Dataset
#
# <a name="cell-id1"></a>

# %%
# If you're not using Colab or Kaggle, uncomment the following line:
# !pip install gsutil
# Out:
# Requirement already satisfied: gsutil in /home/target/.pyenv/versions/3.8.10/lib/python3.8/site-packages (5.34)
# Requirement already satisfied: monotonic>=1.4 in /home/target/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from gsutil) (1.6)
# Requirement already satisfied: six>=1.16.0 in /home/target/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from gsutil) (1.16.0)
# Requirement already satisfied: retry-decorator>=1.0.0 in /home/target/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from gsutil) (1.1.1)
# Requirement already satisfied: google-auth[aiohttp]==2.17.0 in /home/target/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from gsutil) (2.17.0)
# Requirement already satisfied: gcs-oauth2-boto-plugin>=3.2 in /home/target/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from gsutil) (3.2)
# Requirement already satisfied: google-apitools>=0.5.32 in /home/target/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from gsutil) (0.5.32)
# Requirement already satisfied: pyOpenSSL<=24.2.1,>=0.13 in /home/target/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from gsutil) (24.2.1)
# Requirement already satisfied: crcmod>=1.7 in /home/target/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from gsutil) (1.7)
# Requirement already satisfied: google-reauth>=0.1.0 in /home/target/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from gsutil) (0.1.1)
# Requirement already satisfied: argcomplete>=3.5.1 in /home/target/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from gsutil) (3.6.2)
# Requirement already satisfied: httplib2==0.20.4 in /home/target/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from gsutil) (0.20.4)
# Requirement already satisfied: fasteners>=0.14.1 in /home/target/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from gsutil) (0.19)
# Requirement already satisfied: google-auth-httplib2>=0.2.0 in /home/target/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from gsutil) (0.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/target/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from google-auth[aiohttp]==2.17.0->gsutil) (0.4.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/target/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from google-auth[aiohttp]==2.17.0->gsutil) (5.5.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/target/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from google-auth[aiohttp]==2.17.0->gsutil) (4.7.2)
# Requirement already satisfied: aiohttp<4.0.0dev,>=3.6.2 in /home/target/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from google-auth[aiohttp]==2.17.0->gsutil) (3.10.11)
# Requirement already satisfied: requests<3.0.0dev,>=2.20.0 in /home/target/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from google-auth[aiohttp]==2.17.0->gsutil) (2.32.3)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /home/target/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from httplib2==0.20.4->gsutil) (3.1.4)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /home/target/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from aiohttp<4.0.0dev,>=3.6.2->google-auth[aiohttp]==2.17.0->gsutil) (1.15.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/target/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from aiohttp<4.0.0dev,>=3.6.2->google-auth[aiohttp]==2.17.0->gsutil) (2.4.4)
# Requirement already satisfied: attrs>=17.3.0 in /home/target/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from aiohttp<4.0.0dev,>=3.6.2->google-auth[aiohttp]==2.17.0->gsutil) (24.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/target/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from aiohttp<4.0.0dev,>=3.6.2->google-auth[aiohttp]==2.17.0->gsutil) (6.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/target/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from aiohttp<4.0.0dev,>=3.6.2->google-auth[aiohttp]==2.17.0->gsutil) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/target/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from aiohttp<4.0.0dev,>=3.6.2->google-auth[aiohttp]==2.17.0->gsutil) (1.5.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/target/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from aiohttp<4.0.0dev,>=3.6.2->google-auth[aiohttp]==2.17.0->gsutil) (5.0.1)
# Requirement already satisfied: boto>=2.29.1 in /home/target/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from gcs-oauth2-boto-plugin>=3.2->gsutil) (2.49.0)
# Requirement already satisfied: oauth2client>=2.2.0 in /home/target/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from gcs-oauth2-boto-plugin>=3.2->gsutil) (4.1.3)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/target/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from rsa<5,>=3.1.4->google-auth[aiohttp]==2.17.0->gsutil) (0.6.1)
# Requirement already satisfied: pyu2f in /home/target/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from google-reauth>=0.1.0->gsutil) (0.1.5)
# Requirement already satisfied: typing-extensions>=4.1.0 in /home/target/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from multidict<7.0,>=4.5->aiohttp<4.0.0dev,>=3.6.2->google-auth[aiohttp]==2.17.0->gsutil) (4.5.0)
# Requirement already satisfied: cryptography<44,>=41.0.5 in /home/target/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from pyOpenSSL<=24.2.1,>=0.13->gsutil) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /home/target/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from cryptography<44,>=41.0.5->pyOpenSSL<=24.2.1,>=0.13->gsutil) (1.17.1)
# Requirement already satisfied: pycparser in /home/target/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from cffi>=1.12->cryptography<44,>=41.0.5->pyOpenSSL<=24.2.1,>=0.13->gsutil) (2.22)
# Requirement already satisfied: certifi>=2017.4.17 in /home/target/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from requests<3.0.0dev,>=2.20.0->google-auth[aiohttp]==2.17.0->gsutil) (2024.8.30)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/target/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from requests<3.0.0dev,>=2.20.0->google-auth[aiohttp]==2.17.0->gsutil) (2.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/target/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from requests<3.0.0dev,>=2.20.0->google-auth[aiohttp]==2.17.0->gsutil) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/target/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from requests<3.0.0dev,>=2.20.0->google-auth[aiohttp]==2.17.0->gsutil) (3.10)
# Requirement already satisfied: propcache>=0.2.0 in /home/target/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0dev,>=3.6.2->google-auth[aiohttp]==2.17.0->gsutil) (0.2.0)
# WARNING: You are using pip version 21.1.1; however, version 25.0.1 is available.
# You should consider upgrading via the '/home/target/.pyenv/versions/3.8.10/bin/python3.8 -m pip install --upgrade pip' command.

# %%
# %pip install ndjson
# Out:
# Requirement already satisfied: ndjson in /home/target/anaconda3/lib/python3.11/site-packages (0.3.1)
#
# [notice] A new release of pip is available: 23.3.1 -> 25.1.1
# [notice] To update, run: pip3.11 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %mkdir data
# !gsutil -m cp 'gs://quickdraw_dataset/full/simplified/cat.ndjson' ./data
# !gsutil -m cp 'gs://quickdraw_dataset/full/simplified/bus.ndjson' ./data
# !gsutil -m cp 'gs://quickdraw_dataset/full/simplified/rabbit.ndjson' ./data
# Out:
# Copying gs://quickdraw_dataset/full/simplified/cat.ndjson...
# | [1/1 files][ 73.1 MiB/ 73.1 MiB] 100% Done 657.1 KiB/s ETA 00:00:00
# Operation completed over 1 objects/73.1 MiB.
# Copying gs://quickdraw_dataset/full/simplified/bus.ndjson...
# | [1/1 files][ 93.2 MiB/ 93.2 MiB] 100% Done 489.4 KiB/s ETA 00:00:00
# Operation completed over 1 objects/93.2 MiB.
# Copying gs://quickdraw_dataset/full/simplified/rabbit.ndjson...
# | [1/1 files][ 95.0 MiB/ 95.0 MiB] 100% Done 268.4 KiB/s ETA 00:00:00
# Operation completed over 1 objects/95.0 MiB.

# %% [markdown]
# # Solution
#
# - Briefly explain why you chose the method you did.
# - Discuss the drawbacks and advantages of your chosen method.
# - Evaluate and discuss the results for each metric.

# %% [markdown]
# # References
#
# ❗ Do not forget to include the references you used when filling out the notebook.

# %% [markdown]
# - []()
